# %%
import pandas as pd
import numpy as np

# %%
museums = "Resources/museums copy.csv"
museums_df = pd.read_csv(museums)
museums_df.head()
# Out:
# /var/folders/wr/rjq0nc_j49x_y_gtjg3zw9xr0000gn/T/ipykernel_52573/184328106.py:2: DtypeWarning: Columns (9,14,21) have mixed types. Specify dtype option on import or set low_memory=False.
#   museums_df = pd.read_csv(museums)
#     Museum ID                                        Museum Name  \
# 0  8400200098                    ALASKA AVIATION HERITAGE MUSEUM
# 1  8400200117                            ALASKA BOTANICAL GARDEN
# 2  8400200153  ALASKA CHALLENGER CENTER FOR SPACE SCIENCE TEC...
# 3  8400200143                ALASKA EDUCATORS HISTORICAL SOCIETY
# 4  8400200027                             ALASKA HERITAGE MUSEUM
#
#                                           Legal Name Alternate Name  \
# 0                    ALASKA AVIATION HERITAGE MUSEUM            NaN
# 1                        ALASKA BOTANICAL GARDEN INC            NaN
# 2  ALASKA CHALLENGER CENTER FOR SPACE SCIENCE TEC...            NaN
# 3                ALASKA EDUCATORS HISTORICAL SOCIETY            NaN
# ...

# %%
new_columns = ["Museum Name", "Museum Type", "Latitude", "Longitude", "Income", "Revenue"]
museums_df = museums_df.loc[:, new_columns]
museums_df
# Out:
#                                              Museum Name  \
# 0                        ALASKA AVIATION HERITAGE MUSEUM
# 1                                ALASKA BOTANICAL GARDEN
# 2      ALASKA CHALLENGER CENTER FOR SPACE SCIENCE TEC...
# 3                    ALASKA EDUCATORS HISTORICAL SOCIETY
# 4                                 ALASKA HERITAGE MUSEUM
# ...                                                  ...
# 33067                   WYOMING STATE HISTORICAL SOCIETY
# 33068                               WYOMING STATE MUSEUM
# 33069      WYOMING TERRITORIAL PARK HISTORIC ASSOCIATION
# 33070                      WYOMING TRANSPORTATION MUSEUM
# 33071                          YELLOWSTONE NATIONAL PARK
#
#                                          Museum Type  Latitude  Longitude  \
# 0                                     HISTORY MUSEUM  61.17925 -149.97254
# 1      ARBORETUM, BOTANICAL GARDEN, OR NATURE CENTER  61.16890 -149.76708
# ...

# %%
museums_df.dtypes
# Out:
# Museum Name     object
# Museum Type     object
# Latitude       float64
# Longitude      float64
# Income         float64
# Revenue        float64
# dtype: object

# %%
NaN_columns = ["Income", "Revenue"]
museums_df[NaN_columns] = museums_df[NaN_columns].fillna(0.0)
museums_df = museums_df.dropna(how='any')
museums_df.fillna(0.0, inplace=True)
museums_df
# Out:
# /var/folders/wr/rjq0nc_j49x_y_gtjg3zw9xr0000gn/T/ipykernel_52573/1436429483.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   museums_df.fillna(0.0, inplace=True)
#                                              Museum Name  \
# 0                        ALASKA AVIATION HERITAGE MUSEUM
# 1                                ALASKA BOTANICAL GARDEN
# 2      ALASKA CHALLENGER CENTER FOR SPACE SCIENCE TEC...
# 3                    ALASKA EDUCATORS HISTORICAL SOCIETY
# 4                                 ALASKA HERITAGE MUSEUM
# ...                                                  ...
# 33067                   WYOMING STATE HISTORICAL SOCIETY
# 33068                               WYOMING STATE MUSEUM
# 33069      WYOMING TERRITORIAL PARK HISTORIC ASSOCIATION
# ...

# %%
diff_museum_types = museums_df["Museum Type"].unique()
for museums_types in diff_museum_types:
    print(museums_types)
# Out:
# HISTORY MUSEUM
# ARBORETUM, BOTANICAL GARDEN, OR NATURE CENTER
# SCIENCE & TECHNOLOGY MUSEUM OR PLANETARIUM
# HISTORIC PRESERVATION
# GENERAL MUSEUM
# ZOO, AQUARIUM, OR WILDLIFE CONSERVATION
# ART MUSEUM
# CHILDREN'S MUSEUM
# NATURAL HISTORY MUSEUM

# %%
museums_df.to_csv("Resources/museums_df.csv", index=False)

# %%
#museums_df['History Museum'] = museums_df['Museum Type'].str.contains('Hist', case=False)
#museums_df['Art Museum'] = museums_df['Museum Type'].str.contains('Art', case=False)
#museums_df['General Museum'] = museums_df['Museum Type'].str.contains('General', case=False)
#museums_df['Science Museum'] = museums_df['Museum Type'].str.contains('Science', case=False)
#museums_df["Children's Museum"] = museums_df['Museum Type'].str.contains('Children', case=False)
#museums_df['Other Museum'] = museums_df['Museum Type'].str.contains('Zoo|Arboretum', case=False)
#museums_df.head()

# %%
trip_advisor = "Resources/tripadvisor_museum_USonly copy.csv"
trip_advisor_df = pd.read_csv(trip_advisor)
trip_advisor_df.head()
# Out:
#    Unnamed: 0                                            Address  \
# 0           0  555 Pennsylvania Ave NW, Washington DC, DC 200...
# 1           1         1000 5th Ave, New York City, NY 10028-0198
# 2           2    945 Magazine Street, New Orleans, LA 70130-3813
# 3           3        2001 N Colorado Blvd, Denver, CO 80205-5798
# 4           4         111 S Michigan Ave, Chicago, IL 60603-6488
#
#                                          Description  FeatureCount   Fee  \
# 0  Find out for yourself why everyone is calling ...             3  Yes
# 1  At New York City's most visited museum and att...            12  Yes
# 2  Founded by historian and author, Stephen Ambro...            11   NaN
# 3  The Denver Museum of Nature & Science is the R...             0   NaN
# 4  This Classical Renaissance structure, guarded ...             5  Yes
#
#    Langtitude   Latitude       LengthOfVisit  \
# 0  -77.019235  38.893138          2-3 hours
# ...

# %%
drop_tripadvisor_columns = ["Unnamed: 0", "Address", "Description", "FeatureCount", "Fee", 
                            "PhoneNum", "TotalThingsToDo", "LengthOfVisit"]
trip_advisor_df.drop(columns=drop_tripadvisor_columns, inplace=True)
trip_advisor_df = trip_advisor_df.rename(columns={"Langtitude": "Longitude"})
trip_advisor_df.dropna(inplace=True)
trip_advisor_df
# Out:
#        Longitude   Latitude                               MuseumName  Rank  \
# 0     -77.019235  38.893138                                  Newseum     8
# 1     -73.962928  40.779165           The Metropolitan Museum of Art     2
# 2     -90.070086  29.943004                 The National WWII Museum     1
# 3    -104.941020  39.769189        Denver Museum of Nature & Science     4
# 4     -87.623724  41.879547                 Art Institute of Chicago     1
# ...          ...        ...                                      ...   ...
# 1009  -85.820268  33.696549       Anniston Museum of Natural History     1
# 1010 -104.229420  34.466249                     Billy the Kid Museum     1
# 1011  -70.044854  41.291204  Nantucket Shipwreck & Lifesaving Museum    10
# 1012 -118.395063  34.025884            Museum of Jurassic Technology     1
# 1013  -78.929032  35.999047  Nasher Museum of Art at Duke University    13
#
#       Rating ReviewCount
# 0        4.5       6,309
# ...

# %%
trip_advisor_df.dtypes
# Out:
# Longitude      float64
# Latitude       float64
# MuseumName      object
# Rank             int64
# Rating         float64
# ReviewCount     object
# dtype: object

# %%
trip_advisor_df.to_csv("Resources/trip_advisor_df.csv", index=False)

# %%
major_cities = "Resources/uscities.csv"
major_cities_df = pd.read_csv(major_cities)
major_cities_df.head()
# Out:
#           city   city_ascii state_id  state_name  county_fips  county_name  \
# 0     New York     New York       NY    New York        36081       Queens
# 1  Los Angeles  Los Angeles       CA  California         6037  Los Angeles
# 2      Chicago      Chicago       IL    Illinois        17031         Cook
# 3        Miami        Miami       FL     Florida        12086   Miami-Dade
# 4      Houston      Houston       TX       Texas        48201       Harris
#
#        lat       lng  population  density source  military  incorporated  \
# 0  40.6943  -73.9249    18908608  11226.2  shape     False          True
# 1  34.1141 -118.4068    11922389   3202.3  shape     False          True
# 2  41.8375  -87.6866     8497759   4648.7  shape     False          True
# 3  25.7840  -80.2101     6080145   4728.2  shape     False          True
# 4  29.7860  -95.3885     5970127   1382.2  shape     False          True
#
#               timezone  ranking  \
# 0     America/New_York        1
# ...

# %%
grab_columns = ["city", "state_name", "lat", "lng", "population"]
major_cities_df = major_cities_df.loc[:, grab_columns]
major_cities_df.head()
# Out:
#           city  state_name      lat       lng  population
# 0     New York    New York  40.6943  -73.9249    18908608
# 1  Los Angeles  California  34.1141 -118.4068    11922389
# 2      Chicago    Illinois  41.8375  -87.6866     8497759
# 3        Miami     Florida  25.7840  -80.2101     6080145
# 4      Houston       Texas  29.7860  -95.3885     5970127

# %%
major_cities_df = major_cities_df.rename(columns={"city" : "City", "state_name" : "State",
                                                  "lat" : "Latitude", "lng" : "Longitude",
                                                  "population" : "Population"})
major_cities_df.head()
# Out:
#           City       State  Latitude  Longitude  Population
# 0     New York    New York   40.6943   -73.9249    18908608
# 1  Los Angeles  California   34.1141  -118.4068    11922389
# 2      Chicago    Illinois   41.8375   -87.6866     8497759
# 3        Miami     Florida   25.7840   -80.2101     6080145
# 4      Houston       Texas   29.7860   -95.3885     5970127

# %%
major_cities_df = major_cities_df.sort_values(by = "Population", ascending=False)
major_cities_df.head(10)
# Out:
#            City                 State  Latitude  Longitude  Population
# 0      New York              New York   40.6943   -73.9249    18908608
# 1   Los Angeles            California   34.1141  -118.4068    11922389
# 2       Chicago              Illinois   41.8375   -87.6866     8497759
# 3         Miami               Florida   25.7840   -80.2101     6080145
# 4       Houston                 Texas   29.7860   -95.3885     5970127
# 5        Dallas                 Texas   32.7935   -96.7667     5830932
# 6  Philadelphia          Pennsylvania   40.0077   -75.1339     5683533
# 7       Atlanta               Georgia   33.7628   -84.4220     5180179
# 8    Washington  District of Columbia   38.9047   -77.0163     5116378
# 9        Boston         Massachusetts   42.3188   -71.0852     4328315

# %%
major_cities_df = major_cities_df.iloc[:100, :]
major_cities_df.head()
# Out:
#           City       State  Latitude  Longitude  Population
# 0     New York    New York   40.6943   -73.9249    18908608
# 1  Los Angeles  California   34.1141  -118.4068    11922389
# 2      Chicago    Illinois   41.8375   -87.6866     8497759
# 3        Miami     Florida   25.7840   -80.2101     6080145
# 4      Houston       Texas   29.7860   -95.3885     5970127
